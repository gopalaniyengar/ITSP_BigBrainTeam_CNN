# %% [markdown]
# <a href="https://colab.research.google.com/github/gopalaniyengar/ITSP_BigBrainTeam_CNN/blob/Gopalan/ITSP_Proj_MK2_Part_2_v2.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/pwd
# Out:
# '/content'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import numpy as np
import sklearn
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import transforms

# %%
transform=transforms.ToTensor()
trainset=datasets.EMNIST(root='/content/drive/My Drive/Colab Notebooks/data', split= 'byclass', train=True, download=True, transform=transform)
testset=datasets.EMNIST(root='/content/drive/My Drive/Colab Notebooks/data', split= 'byclass', train=False, download=True, transform=transform)
print(len(trainset))
print(len(testset))
print(len(trainset)+len(testset))
print(1)
# Out:
# 697932
# 116323
# 814255
# 1

# %%
batch=32
numberofbatches=697932/32
print(numberofbatches)
numberofbatches=21811
print(numberofbatches)
trainloadeddata=DataLoader(trainset, batch_size=batch, shuffle= True)
testloadeddata=DataLoader(testset, batch_size=batch, shuffle= True)
#for batchno,(image, labels) in enumerate(trainloadeddata):
    #if  batchno==1:
     #print(image, labels)
# Out:
# 21810.375
# 21811

# %%
class ModelOfNet(nn.Module):
    def __init__(self):
        super(ModelOfNet,self).__init__()

        self.convolve=nn.Sequential(
                nn.Conv2d(1,8,3,1,1),
                nn.ReLU(),
                nn.Conv2d(8,16,3,1,1),
                nn.ReLU(),
                nn.BatchNorm2d(16),
                nn.MaxPool2d(2,2),
                nn.Conv2d(16,32,3,1,1),
                nn.ReLU(),
                nn.BatchNorm2d(32),
                nn.MaxPool2d(2,2),
        )
        self.fullyconnect=nn.Linear(1568,62)

    def forward(self, x):
        x=self.convolve(x)
        x=x.view(x.size(0),-1)
        x=self.fullyconnect(x)
        return x 
    print('I sure hope this model works fine this time without any errors')
# Out:
# I sure hope this model works fine this time without any errors

# %%
MYNN=ModelOfNet()
print(MYNN)
classwts=torch.load('/content/drive/My Drive/Colab Notebooks/lossweights.pt')
print(classwts)
print(classwts.dtype)
lossfunction=torch.nn.CrossEntropyLoss(weight=classwts)
updatefunction=torch.optim.Adam(MYNN.parameters(), lr=0.00001)
print('completed running block')
# Out:
# ModelOfNet(
#   (convolve): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fullyconnect): Linear(in_features=1568, out_features=62, bias=True)
# )
# tensor([0.3255, 0.2933, 0.3291, 0.3203, 0.3357, 0.3583, 0.3288, 0.3148, 0.3316,
#         0.3326, 1.7570, 2.9028, 1.1152, 2.4676, 2.2815, 1.2260, 4.4724, 3.5714,
#         0.9423, 2.9923, 4.5612, 2.2177, 1.2505, 1.3666, 0.4506, 1.3486, 4.3213,
#         2.2190, 0.5421, 1.1463, 0.8933, 2.4276, 2.3977, 4.0624, 2.3734, 4.1677,
#         1.1220, 2.1820, 3.9443, 1.1061, 0.4570, 4.3955, 3.0532, 1.2883, 4.1310,
#         5.9372, 4.5191, 0.7349, 4.2559, 0.9859, 4.0949, 4.5984, 3.7598, 0.7981,
#         4.1708, 0.6164, 3.9777, 3.8684, 4.1739, 3.9890, 4.7598, 4.1310])
# torch.float32
# completed running block

# %%
def validationtrainingtime(epochs):
  avglossoverepochs=[]
  accuracyoverepochs=[]
  for i in range(epochs):
    sum=0.0
    avgaccuracyoverepoch=0.0
    sumbatch=0.0
    for batchno,(image, labels) in enumerate(trainloadeddata):
      updatefunction.zero_grad()
      resultofmodel=MYNN(image)
      
      losscalc=lossfunction(resultofmodel, labels)
      resultofmodel=F.softmax(resultofmodel, dim=1)
      #print(resultofmodel.shape)
      pred=torch.argmax(resultofmodel, dim=1)
      #print(pred)
      
      count=0.0
      assert pred.shape[0]==labels.shape[0]
      for j in range(pred.shape[0]):
        if pred[j]==labels[j]:
          count=count+1.0
      
      batchaccuracy=(count/pred.shape[0])*100
      sum=sum+losscalc
      sumbatch=sumbatch+losscalc
      losscalc.backward()
      updatefunction.step()

      if batchno%1000==True:
        print(i, batchno, "Batch Loss:", losscalc,"Batch Accuracy=", batchaccuracy,"%", "Average Loss Over 1000 Batches:", (sumbatch/1000))
        sumbatch=0.0
      avgaccuracyoverepoch=avgaccuracyoverepoch+(batchaccuracy/numberofbatches)
      if batchno==17500:
        break

    print("Average Loss over Epoch:", (sum/numberofbatches))
    print("Average Accuracy over Epoch:", avgaccuracyoverepoch, "%")
    accuracyoverepochs.append(avgaccuracyoverepoch)
    avglossoverepochs.append((sum/numberofbatches))
    avgvalidationaccuracyoverepoch=0.0
    for batchno2,(image2,labels2) in enumerate(trainloadeddata):
      if batchno2>17500:  
        with torch.no_grad():
            resultofmodel2=MYNN(image2)
            losscalc2=lossfunction(resultofmodel2, labels2)
            resultofmodel2=F.softmax(resultofmodel2, dim=1)
            #print(resultofmodel2.shape)
            pred2=torch.argmax(resultofmodel2, dim=1)
            #print(pred2)
            
            count2=0.0
            assert pred2.shape[0]==labels2.shape[0]
            for k in range(pred2.shape[0]):
              if pred2[k]==labels2[k]:
                count2=count2+1.0
            batchaccuracy2=(count2/pred2.shape[0])*100

            if batchno2%100==True:
              print(i, batchno2, "Batch Validation Accuracy=", batchaccuracy2, "%")

            avgvalidationaccuracyoverepoch=avgvalidationaccuracyoverepoch+(batchaccuracy2/(numberofbatches-17500))
  
  print('hopefully i reach this part of the function')
  print(accuracyoverepochs)
  print(avglossoverepochs)
  print(avgvalidationaccuracyoverepoch)

# %%
epoch=5
validationtrainingtime(epoch)
# Out:
# 0 1 Batch Loss: tensor(1.1832, grad_fn=<NllLossBackward>) Batch Accuracy= 62.5 % Average Loss Over 1000 Batches: tensor(0.0017, grad_fn=<DivBackward0>)
# 0 1001 Batch Loss: tensor(0.6888, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.8037, grad_fn=<DivBackward0>)
# 0 2001 Batch Loss: tensor(0.7293, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.7988, grad_fn=<DivBackward0>)
# 0 3001 Batch Loss: tensor(0.9917, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.7970, grad_fn=<DivBackward0>)
# 0 4001 Batch Loss: tensor(0.5373, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.7913, grad_fn=<DivBackward0>)
# 0 5001 Batch Loss: tensor(1.3574, grad_fn=<NllLossBackward>) Batch Accuracy= 68.75 % Average Loss Over 1000 Batches: tensor(0.7870, grad_fn=<DivBackward0>)
# 0 6001 Batch Loss: tensor(0.6332, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.7964, grad_fn=<DivBackward0>)
# 0 7001 Batch Loss: tensor(0.7748, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.7870, grad_fn=<DivBackward0>)
# 0 8001 Batch Loss: tensor(0.9355, grad_fn=<NllLossBackward>) Batch Accuracy= 68.75 % Average Loss Over 1000 Batches: tensor(0.7769, grad_fn=<DivBackward0>)
# 0 9001 Batch Loss: tensor(0.5197, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.7811, grad_fn=<DivBackward0>)
# 0 10001 Batch Loss: tensor(0.5001, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.7726, grad_fn=<DivBackward0>)
# 0 11001 Batch Loss: tensor(0.6931, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.7740, grad_fn=<DivBackward0>)
# 0 12001 Batch Loss: tensor(0.5987, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.7733, grad_fn=<DivBackward0>)
# 0 13001 Batch Loss: tensor(0.3369, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.7721, grad_fn=<DivBackward0>)
# 0 14001 Batch Loss: tensor(0.7076, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.7660, grad_fn=<DivBackward0>)
# 0 15001 Batch Loss: tensor(0.6300, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.7514, grad_fn=<DivBackward0>)
# 0 16001 Batch Loss: tensor(0.5709, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.7777, grad_fn=<DivBackward0>)
# 0 17001 Batch Loss: tensor(1.1474, grad_fn=<NllLossBackward>) Batch Accuracy= 62.5 % Average Loss Over 1000 Batches: tensor(0.7528, grad_fn=<DivBackward0>)
# Average Loss over Epoch: tensor(0.6253, grad_fn=<DivBackward0>)
# Average Accuracy over Epoch: 60.96035257437385 %
# 0 17501 Batch Validation Accuracy= 84.375 %
# 0 17601 Batch Validation Accuracy= 68.75 %
# 0 17701 Batch Validation Accuracy= 81.25 %
# 0 17801 Batch Validation Accuracy= 81.25 %
# 0 17901 Batch Validation Accuracy= 75.0 %
# 0 18001 Batch Validation Accuracy= 68.75 %
# 0 18101 Batch Validation Accuracy= 84.375 %
# 0 18201 Batch Validation Accuracy= 81.25 %
# 0 18301 Batch Validation Accuracy= 78.125 %
# 0 18401 Batch Validation Accuracy= 71.875 %
# 0 18501 Batch Validation Accuracy= 90.625 %
# 0 18601 Batch Validation Accuracy= 75.0 %
# 0 18701 Batch Validation Accuracy= 71.875 %
# 0 18801 Batch Validation Accuracy= 81.25 %
# 0 18901 Batch Validation Accuracy= 78.125 %
# 0 19001 Batch Validation Accuracy= 81.25 %
# 0 19101 Batch Validation Accuracy= 65.625 %
# 0 19201 Batch Validation Accuracy= 78.125 %
# 0 19301 Batch Validation Accuracy= 84.375 %
# 0 19401 Batch Validation Accuracy= 71.875 %
# 0 19501 Batch Validation Accuracy= 71.875 %
# 0 19601 Batch Validation Accuracy= 75.0 %
# 0 19701 Batch Validation Accuracy= 75.0 %
# 0 19801 Batch Validation Accuracy= 75.0 %
# 0 19901 Batch Validation Accuracy= 71.875 %
# 0 20001 Batch Validation Accuracy= 78.125 %
# 0 20101 Batch Validation Accuracy= 71.875 %
# 0 20201 Batch Validation Accuracy= 75.0 %
# 0 20301 Batch Validation Accuracy= 68.75 %
# 0 20401 Batch Validation Accuracy= 81.25 %
# 0 20501 Batch Validation Accuracy= 78.125 %
# 0 20601 Batch Validation Accuracy= 84.375 %
# 0 20701 Batch Validation Accuracy= 78.125 %
# 0 20801 Batch Validation Accuracy= 84.375 %
# 0 20901 Batch Validation Accuracy= 75.0 %
# 0 21001 Batch Validation Accuracy= 78.125 %
# 0 21101 Batch Validation Accuracy= 81.25 %
# 0 21201 Batch Validation Accuracy= 87.5 %
# 0 21301 Batch Validation Accuracy= 87.5 %
# 0 21401 Batch Validation Accuracy= 81.25 %
# 0 21501 Batch Validation Accuracy= 75.0 %
# 0 21601 Batch Validation Accuracy= 75.0 %
# 0 21701 Batch Validation Accuracy= 78.125 %
# 0 21801 Batch Validation Accuracy= 81.25 %
# 1 1 Batch Loss: tensor(0.5203, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.0011, grad_fn=<DivBackward0>)
# 1 1001 Batch Loss: tensor(0.6106, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.7428, grad_fn=<DivBackward0>)
# 1 2001 Batch Loss: tensor(0.6859, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.7458, grad_fn=<DivBackward0>)
# 1 3001 Batch Loss: tensor(0.6794, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.7308, grad_fn=<DivBackward0>)
# 1 4001 Batch Loss: tensor(1.0531, grad_fn=<NllLossBackward>) Batch Accuracy= 62.5 % Average Loss Over 1000 Batches: tensor(0.7416, grad_fn=<DivBackward0>)
# 1 5001 Batch Loss: tensor(0.7941, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.7286, grad_fn=<DivBackward0>)
# 1 6001 Batch Loss: tensor(1.0313, grad_fn=<NllLossBackward>) Batch Accuracy= 62.5 % Average Loss Over 1000 Batches: tensor(0.7382, grad_fn=<DivBackward0>)
# 1 7001 Batch Loss: tensor(0.5274, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.7371, grad_fn=<DivBackward0>)
# 1 8001 Batch Loss: tensor(0.4513, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.7203, grad_fn=<DivBackward0>)
# 1 9001 Batch Loss: tensor(0.8829, grad_fn=<NllLossBackward>) Batch Accuracy= 65.625 % Average Loss Over 1000 Batches: tensor(0.7337, grad_fn=<DivBackward0>)
# 1 10001 Batch Loss: tensor(0.3842, grad_fn=<NllLossBackward>) Batch Accuracy= 90.625 % Average Loss Over 1000 Batches: tensor(0.7108, grad_fn=<DivBackward0>)
# 1 11001 Batch Loss: tensor(1.0122, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.7144, grad_fn=<DivBackward0>)
# 1 12001 Batch Loss: tensor(0.3660, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.7093, grad_fn=<DivBackward0>)
# 1 13001 Batch Loss: tensor(0.2987, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.7210, grad_fn=<DivBackward0>)
# 1 14001 Batch Loss: tensor(0.4774, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.7140, grad_fn=<DivBackward0>)
# 1 15001 Batch Loss: tensor(0.8676, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.7092, grad_fn=<DivBackward0>)
# 1 16001 Batch Loss: tensor(0.2566, grad_fn=<NllLossBackward>) Batch Accuracy= 90.625 % Average Loss Over 1000 Batches: tensor(0.6968, grad_fn=<DivBackward0>)
# 1 17001 Batch Loss: tensor(1.0704, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.7209, grad_fn=<DivBackward0>)
# Average Loss over Epoch: tensor(0.5809, grad_fn=<DivBackward0>)
# Average Accuracy over Epoch: 61.945807161508725 %
# 1 17501 Batch Validation Accuracy= 87.5 %
# 1 17601 Batch Validation Accuracy= 81.25 %
# 1 17701 Batch Validation Accuracy= 71.875 %
# 1 17801 Batch Validation Accuracy= 90.625 %
# 1 17901 Batch Validation Accuracy= 78.125 %
# 1 18001 Batch Validation Accuracy= 81.25 %
# 1 18101 Batch Validation Accuracy= 78.125 %
# 1 18201 Batch Validation Accuracy= 71.875 %
# 1 18301 Batch Validation Accuracy= 65.625 %
# 1 18401 Batch Validation Accuracy= 84.375 %
# 1 18501 Batch Validation Accuracy= 75.0 %
# 1 18601 Batch Validation Accuracy= 81.25 %
# 1 18701 Batch Validation Accuracy= 81.25 %
# 1 18801 Batch Validation Accuracy= 71.875 %
# 1 18901 Batch Validation Accuracy= 84.375 %
# 1 19001 Batch Validation Accuracy= 71.875 %
# 1 19101 Batch Validation Accuracy= 81.25 %
# 1 19201 Batch Validation Accuracy= 75.0 %
# 1 19301 Batch Validation Accuracy= 87.5 %
# 1 19401 Batch Validation Accuracy= 81.25 %
# 1 19501 Batch Validation Accuracy= 78.125 %
# 1 19601 Batch Validation Accuracy= 75.0 %
# 1 19701 Batch Validation Accuracy= 93.75 %
# 1 19801 Batch Validation Accuracy= 71.875 %
# 1 19901 Batch Validation Accuracy= 75.0 %
# 1 20001 Batch Validation Accuracy= 81.25 %
# 1 20101 Batch Validation Accuracy= 71.875 %
# 1 20201 Batch Validation Accuracy= 84.375 %
# 1 20301 Batch Validation Accuracy= 75.0 %
# 1 20401 Batch Validation Accuracy= 84.375 %
# 1 20501 Batch Validation Accuracy= 68.75 %
# 1 20601 Batch Validation Accuracy= 78.125 %
# 1 20701 Batch Validation Accuracy= 75.0 %
# 1 20801 Batch Validation Accuracy= 81.25 %
# 1 20901 Batch Validation Accuracy= 81.25 %
# 1 21001 Batch Validation Accuracy= 84.375 %
# 1 21101 Batch Validation Accuracy= 68.75 %
# 1 21201 Batch Validation Accuracy= 84.375 %
# 1 21301 Batch Validation Accuracy= 62.5 %
# 1 21401 Batch Validation Accuracy= 78.125 %
# 1 21501 Batch Validation Accuracy= 68.75 %
# 1 21601 Batch Validation Accuracy= 81.25 %
# 1 21701 Batch Validation Accuracy= 84.375 %
# 1 21801 Batch Validation Accuracy= 75.0 %
# 2 1 Batch Loss: tensor(0.5714, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.0014, grad_fn=<DivBackward0>)
# 2 1001 Batch Loss: tensor(0.6204, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.6944, grad_fn=<DivBackward0>)
# 2 2001 Batch Loss: tensor(0.5096, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6947, grad_fn=<DivBackward0>)
# 2 3001 Batch Loss: tensor(0.3347, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.7032, grad_fn=<DivBackward0>)
# 2 4001 Batch Loss: tensor(0.7802, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.7056, grad_fn=<DivBackward0>)
# 2 5001 Batch Loss: tensor(0.6483, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.7093, grad_fn=<DivBackward0>)
# 2 6001 Batch Loss: tensor(0.6437, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6852, grad_fn=<DivBackward0>)
# 2 7001 Batch Loss: tensor(0.4421, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6776, grad_fn=<DivBackward0>)
# 2 8001 Batch Loss: tensor(0.5075, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6889, grad_fn=<DivBackward0>)
# 2 9001 Batch Loss: tensor(1.0631, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.6963, grad_fn=<DivBackward0>)
# 2 10001 Batch Loss: tensor(1.0222, grad_fn=<NllLossBackward>) Batch Accuracy= 65.625 % Average Loss Over 1000 Batches: tensor(0.6906, grad_fn=<DivBackward0>)
# 2 11001 Batch Loss: tensor(1.0613, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6893, grad_fn=<DivBackward0>)
# 2 12001 Batch Loss: tensor(1.3616, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.6907, grad_fn=<DivBackward0>)
# 2 13001 Batch Loss: tensor(0.4806, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.6694, grad_fn=<DivBackward0>)
# 2 14001 Batch Loss: tensor(0.5405, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6803, grad_fn=<DivBackward0>)
# 2 15001 Batch Loss: tensor(0.9273, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6968, grad_fn=<DivBackward0>)
# 2 16001 Batch Loss: tensor(0.4713, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6738, grad_fn=<DivBackward0>)
# 2 17001 Batch Loss: tensor(1.0243, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6769, grad_fn=<DivBackward0>)
# Average Loss over Epoch: tensor(0.5527, grad_fn=<DivBackward0>)
# Average Accuracy over Epoch: 62.53037458161761 %
# 2 17501 Batch Validation Accuracy= 87.5 %
# 2 17601 Batch Validation Accuracy= 75.0 %
# 2 17701 Batch Validation Accuracy= 75.0 %
# 2 17801 Batch Validation Accuracy= 78.125 %
# 2 17901 Batch Validation Accuracy= 90.625 %
# 2 18001 Batch Validation Accuracy= 78.125 %
# 2 18101 Batch Validation Accuracy= 87.5 %
# 2 18201 Batch Validation Accuracy= 78.125 %
# 2 18301 Batch Validation Accuracy= 90.625 %
# 2 18401 Batch Validation Accuracy= 78.125 %
# 2 18501 Batch Validation Accuracy= 71.875 %
# 2 18601 Batch Validation Accuracy= 81.25 %
# 2 18701 Batch Validation Accuracy= 71.875 %
# 2 18801 Batch Validation Accuracy= 81.25 %
# 2 18901 Batch Validation Accuracy= 84.375 %
# 2 19001 Batch Validation Accuracy= 68.75 %
# 2 19101 Batch Validation Accuracy= 84.375 %
# 2 19201 Batch Validation Accuracy= 78.125 %
# 2 19301 Batch Validation Accuracy= 71.875 %
# 2 19401 Batch Validation Accuracy= 84.375 %
# 2 19501 Batch Validation Accuracy= 84.375 %
# 2 19601 Batch Validation Accuracy= 87.5 %
# 2 19701 Batch Validation Accuracy= 71.875 %
# 2 19801 Batch Validation Accuracy= 81.25 %
# 2 19901 Batch Validation Accuracy= 87.5 %
# 2 20001 Batch Validation Accuracy= 71.875 %
# 2 20101 Batch Validation Accuracy= 78.125 %
# 2 20201 Batch Validation Accuracy= 75.0 %
# 2 20301 Batch Validation Accuracy= 62.5 %
# 2 20401 Batch Validation Accuracy= 84.375 %
# 2 20501 Batch Validation Accuracy= 75.0 %
# 2 20601 Batch Validation Accuracy= 71.875 %
# 2 20701 Batch Validation Accuracy= 78.125 %
# 2 20801 Batch Validation Accuracy= 90.625 %
# 2 20901 Batch Validation Accuracy= 78.125 %
# 2 21001 Batch Validation Accuracy= 87.5 %
# 2 21101 Batch Validation Accuracy= 65.625 %
# 2 21201 Batch Validation Accuracy= 75.0 %
# 2 21301 Batch Validation Accuracy= 84.375 %
# 2 21401 Batch Validation Accuracy= 71.875 %
# 2 21501 Batch Validation Accuracy= 71.875 %
# 2 21601 Batch Validation Accuracy= 81.25 %
# 2 21701 Batch Validation Accuracy= 90.625 %
# 2 21801 Batch Validation Accuracy= 68.75 %
# 3 1 Batch Loss: tensor(0.5075, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.0017, grad_fn=<DivBackward0>)
# 3 1001 Batch Loss: tensor(0.6478, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6788, grad_fn=<DivBackward0>)
# 3 2001 Batch Loss: tensor(0.9073, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.6767, grad_fn=<DivBackward0>)
# 3 3001 Batch Loss: tensor(0.6775, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6460, grad_fn=<DivBackward0>)
# 3 4001 Batch Loss: tensor(0.5642, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.6554, grad_fn=<DivBackward0>)
# 3 5001 Batch Loss: tensor(0.7323, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6577, grad_fn=<DivBackward0>)
# 3 6001 Batch Loss: tensor(0.2525, grad_fn=<NllLossBackward>) Batch Accuracy= 90.625 % Average Loss Over 1000 Batches: tensor(0.6658, grad_fn=<DivBackward0>)
# 3 7001 Batch Loss: tensor(1.0300, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6727, grad_fn=<DivBackward0>)
# 3 8001 Batch Loss: tensor(0.6984, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.6591, grad_fn=<DivBackward0>)
# 3 9001 Batch Loss: tensor(0.4488, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6516, grad_fn=<DivBackward0>)
# 3 10001 Batch Loss: tensor(0.5904, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.6720, grad_fn=<DivBackward0>)
# 3 11001 Batch Loss: tensor(0.5100, grad_fn=<NllLossBackward>) Batch Accuracy= 68.75 % Average Loss Over 1000 Batches: tensor(0.6581, grad_fn=<DivBackward0>)
# 3 12001 Batch Loss: tensor(0.5729, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6650, grad_fn=<DivBackward0>)
# 3 13001 Batch Loss: tensor(0.4115, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6598, grad_fn=<DivBackward0>)
# 3 14001 Batch Loss: tensor(0.9750, grad_fn=<NllLossBackward>) Batch Accuracy= 62.5 % Average Loss Over 1000 Batches: tensor(0.6709, grad_fn=<DivBackward0>)
# 3 15001 Batch Loss: tensor(1.2940, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6546, grad_fn=<DivBackward0>)
# 3 16001 Batch Loss: tensor(0.6247, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6575, grad_fn=<DivBackward0>)
# 3 17001 Batch Loss: tensor(0.9838, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6463, grad_fn=<DivBackward0>)
# Average Loss over Epoch: tensor(0.5305, grad_fn=<DivBackward0>)
# Average Accuracy over Epoch: 62.947165421102405 %
# 3 17501 Batch Validation Accuracy= 71.875 %
# 3 17601 Batch Validation Accuracy= 71.875 %
# 3 17701 Batch Validation Accuracy= 75.0 %
# 3 17801 Batch Validation Accuracy= 84.375 %
# 3 17901 Batch Validation Accuracy= 90.625 %
# 3 18001 Batch Validation Accuracy= 78.125 %
# 3 18101 Batch Validation Accuracy= 75.0 %
# 3 18201 Batch Validation Accuracy= 68.75 %
# 3 18301 Batch Validation Accuracy= 87.5 %
# 3 18401 Batch Validation Accuracy= 81.25 %
# 3 18501 Batch Validation Accuracy= 81.25 %
# 3 18601 Batch Validation Accuracy= 65.625 %
# 3 18701 Batch Validation Accuracy= 78.125 %
# 3 18801 Batch Validation Accuracy= 81.25 %
# 3 18901 Batch Validation Accuracy= 71.875 %
# 3 19001 Batch Validation Accuracy= 81.25 %
# 3 19101 Batch Validation Accuracy= 78.125 %
# 3 19201 Batch Validation Accuracy= 84.375 %
# 3 19301 Batch Validation Accuracy= 75.0 %
# 3 19401 Batch Validation Accuracy= 81.25 %
# 3 19501 Batch Validation Accuracy= 71.875 %
# 3 19601 Batch Validation Accuracy= 87.5 %
# 3 19701 Batch Validation Accuracy= 81.25 %
# 3 19801 Batch Validation Accuracy= 84.375 %
# 3 19901 Batch Validation Accuracy= 84.375 %
# 3 20001 Batch Validation Accuracy= 87.5 %
# 3 20101 Batch Validation Accuracy= 78.125 %
# 3 20201 Batch Validation Accuracy= 81.25 %
# 3 20301 Batch Validation Accuracy= 78.125 %
# 3 20401 Batch Validation Accuracy= 62.5 %
# 3 20501 Batch Validation Accuracy= 71.875 %
# 3 20601 Batch Validation Accuracy= 81.25 %
# 3 20701 Batch Validation Accuracy= 62.5 %
# 3 20801 Batch Validation Accuracy= 75.0 %
# 3 20901 Batch Validation Accuracy= 78.125 %
# 3 21001 Batch Validation Accuracy= 75.0 %
# 3 21101 Batch Validation Accuracy= 78.125 %
# 3 21201 Batch Validation Accuracy= 78.125 %
# 3 21301 Batch Validation Accuracy= 68.75 %
# 3 21401 Batch Validation Accuracy= 87.5 %
# 3 21501 Batch Validation Accuracy= 84.375 %
# 3 21601 Batch Validation Accuracy= 75.0 %
# 3 21701 Batch Validation Accuracy= 68.75 %
# 3 21801 Batch Validation Accuracy= 78.125 %
# 4 1 Batch Loss: tensor(0.5271, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.0013, grad_fn=<DivBackward0>)
# 4 1001 Batch Loss: tensor(0.6962, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6392, grad_fn=<DivBackward0>)
# 4 2001 Batch Loss: tensor(0.8820, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6593, grad_fn=<DivBackward0>)
# 4 3001 Batch Loss: tensor(0.4548, grad_fn=<NllLossBackward>) Batch Accuracy= 87.5 % Average Loss Over 1000 Batches: tensor(0.6512, grad_fn=<DivBackward0>)
# 4 4001 Batch Loss: tensor(0.8635, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6390, grad_fn=<DivBackward0>)
# 4 5001 Batch Loss: tensor(0.7125, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6334, grad_fn=<DivBackward0>)
# 4 6001 Batch Loss: tensor(0.8462, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6369, grad_fn=<DivBackward0>)
# 4 7001 Batch Loss: tensor(1.3899, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.6374, grad_fn=<DivBackward0>)
# 4 8001 Batch Loss: tensor(0.4786, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6373, grad_fn=<DivBackward0>)
# 4 9001 Batch Loss: tensor(0.7606, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.6370, grad_fn=<DivBackward0>)
# 4 10001 Batch Loss: tensor(0.8222, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.6473, grad_fn=<DivBackward0>)
# 4 11001 Batch Loss: tensor(0.4293, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6340, grad_fn=<DivBackward0>)
# 4 12001 Batch Loss: tensor(0.6736, grad_fn=<NllLossBackward>) Batch Accuracy= 71.875 % Average Loss Over 1000 Batches: tensor(0.6567, grad_fn=<DivBackward0>)
# 4 13001 Batch Loss: tensor(0.8478, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6494, grad_fn=<DivBackward0>)
# 4 14001 Batch Loss: tensor(0.4081, grad_fn=<NllLossBackward>) Batch Accuracy= 84.375 % Average Loss Over 1000 Batches: tensor(0.6421, grad_fn=<DivBackward0>)
# 4 15001 Batch Loss: tensor(0.4763, grad_fn=<NllLossBackward>) Batch Accuracy= 81.25 % Average Loss Over 1000 Batches: tensor(0.6380, grad_fn=<DivBackward0>)
# 4 16001 Batch Loss: tensor(0.9996, grad_fn=<NllLossBackward>) Batch Accuracy= 75.0 % Average Loss Over 1000 Batches: tensor(0.6223, grad_fn=<DivBackward0>)
# 4 17001 Batch Loss: tensor(0.5999, grad_fn=<NllLossBackward>) Batch Accuracy= 78.125 % Average Loss Over 1000 Batches: tensor(0.6326, grad_fn=<DivBackward0>)
# Average Loss over Epoch: tensor(0.5142, grad_fn=<DivBackward0>)
# Average Accuracy over Epoch: 63.3579386547919 %
# 4 17501 Batch Validation Accuracy= 78.125 %
# 4 17601 Batch Validation Accuracy= 65.625 %
# 4 17701 Batch Validation Accuracy= 75.0 %
# 4 17801 Batch Validation Accuracy= 90.625 %
# 4 17901 Batch Validation Accuracy= 71.875 %
# 4 18001 Batch Validation Accuracy= 93.75 %
# 4 18101 Batch Validation Accuracy= 75.0 %
# 4 18201 Batch Validation Accuracy= 78.125 %
# 4 18301 Batch Validation Accuracy= 90.625 %
# 4 18401 Batch Validation Accuracy= 71.875 %
# 4 18501 Batch Validation Accuracy= 81.25 %
# 4 18601 Batch Validation Accuracy= 78.125 %
# 4 18701 Batch Validation Accuracy= 78.125 %
# 4 18801 Batch Validation Accuracy= 78.125 %
# 4 18901 Batch Validation Accuracy= 81.25 %
# 4 19001 Batch Validation Accuracy= 81.25 %
# 4 19101 Batch Validation Accuracy= 75.0 %
# 4 19201 Batch Validation Accuracy= 75.0 %
# 4 19301 Batch Validation Accuracy= 84.375 %
# 4 19401 Batch Validation Accuracy= 81.25 %
# 4 19501 Batch Validation Accuracy= 71.875 %
# 4 19601 Batch Validation Accuracy= 90.625 %
# 4 19701 Batch Validation Accuracy= 87.5 %
# 4 19801 Batch Validation Accuracy= 75.0 %
# 4 19901 Batch Validation Accuracy= 87.5 %
# 4 20001 Batch Validation Accuracy= 81.25 %
# 4 20101 Batch Validation Accuracy= 84.375 %
# 4 20201 Batch Validation Accuracy= 78.125 %
# 4 20301 Batch Validation Accuracy= 81.25 %
# 4 20401 Batch Validation Accuracy= 71.875 %
# 4 20501 Batch Validation Accuracy= 71.875 %
# 4 20601 Batch Validation Accuracy= 71.875 %
# 4 20701 Batch Validation Accuracy= 78.125 %
# 4 20801 Batch Validation Accuracy= 90.625 %
# 4 20901 Batch Validation Accuracy= 93.75 %
# 4 21001 Batch Validation Accuracy= 75.0 %
# 4 21101 Batch Validation Accuracy= 65.625 %
# 4 21201 Batch Validation Accuracy= 84.375 %
# 4 21301 Batch Validation Accuracy= 78.125 %
# 4 21401 Batch Validation Accuracy= 78.125 %
# 4 21501 Batch Validation Accuracy= 81.25 %
# 4 21601 Batch Validation Accuracy= 78.125 %
# 4 21701 Batch Validation Accuracy= 78.125 %
# 4 21801 Batch Validation Accuracy= 87.5 %
# hopefully i reach this part of the function
# [60.96035257437385, 61.945807161508725, 62.53037458161761, 62.947165421102405, 63.3579386547919]
# [tensor(0.6253, grad_fn=<DivBackward0>), tensor(0.5809, grad_fn=<DivBackward0>), tensor(0.5527, grad_fn=<DivBackward0>), tensor(0.5305, grad_fn=<DivBackward0>), tensor(0.5142, grad_fn=<DivBackward0>)]
# 79.36673625609009
